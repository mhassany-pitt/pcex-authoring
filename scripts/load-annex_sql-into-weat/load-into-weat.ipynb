# %%
# import json
# import requests

# weat = json.load(open("weat_sql--final.json"))

# for source in weat:
#     source['lines'] = {ln: {"comments":[{"content": line[0]}]} for ln, line in source['lines'].items()}
    
# json.dump(weat, open("weat_sql--final.json", "w"), indent=2)

# %%
# import json
# import requests

# weat = json.load(open("weat_sql--final.json"))

# for index, source in enumerate(weat):
#     resp = requests.post("http://adapt2.sis.pitt.edu/pcex-authoring/api/bulk/sources", 
#                          headers={"api-token": open("weat_api_token.txt").read().strip()},
#                          json=source)
#     print(f"[{index}/{len(weat)}]: {resp.status_code} - {resp.text}")
# Out:
# [0/65]: 201 - {"id":"69af0382fed23847a6dd3711"}
# [1/65]: 201 - {"id":"69af0384fed23847a6dd3714"}
# [2/65]: 201 - {"id":"69af0385fed23847a6dd3717"}
# [3/65]: 201 - {"id":"69af0386fed23847a6dd371a"}
# [4/65]: 201 - {"id":"69af0387fed23847a6dd371d"}
# [5/65]: 201 - {"id":"69af0388fed23847a6dd3720"}
# [6/65]: 201 - {"id":"69af038afed23847a6dd3723"}
# [7/65]: 201 - {"id":"69af038bfed23847a6dd3726"}
# [8/65]: 201 - {"id":"69af038cfed23847a6dd3729"}
# [9/65]: 201 - {"id":"69af038dfed23847a6dd372c"}
# [10/65]: 201 - {"id":"69af038ffed23847a6dd372f"}
# [11/65]: 201 - {"id":"69af0390fed23847a6dd3732"}
# [12/65]: 201 - {"id":"69af0391fed23847a6dd3735"}
# [13/65]: 201 - {"id":"69af0392fed23847a6dd3738"}
# [14/65]: 201 - {"id":"69af0393fed23847a6dd373b"}
# [15/65]: 201 - {"id":"69af0395fed23847a6dd373e"}
# [16/65]: 201 - {"id":"69af0396fed23847a6dd3741"}
# [17/65]: 201 - {"id":"69af0397fed23847a6dd3744"}
# [18/65]: 201 - {"id":"69af0398fed23847a6dd3747"}
# ...
