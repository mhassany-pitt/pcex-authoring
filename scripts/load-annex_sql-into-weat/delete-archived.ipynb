# %%
# import json
# import requests

# archived = [source for source in json.load(open("moh70-sources.json")) if source.get("archived")]

# for index, source in enumerate(archived):
#     if source.get("archived"):
#         resp = requests.delete(f"http://adapt2.sis.pitt.edu/pcex-authoring/api/bulk/sources/{source['id']}?user={source['user']}", 
#                             headers={"api-token": open("weat_api_token.txt").read().strip()})
#         print(f"[{index}/{len(archived)}]: {resp.status_code} - {resp.text}")

# %%
# import json
# import requests

# archived = [activity for activity in json.load(open("moh70-activities.json")) if activity.get("archived")]
# archived = [activity for activity in archived if activity.get("name") in ["Pokazivacka aritmetika","mg-pcex-test-final","mgpcextest","mg-pcex-test-07","mg-pcex-test-06","mg-pcex-test-05","mg-pcex-test-04","mg-pcex-test-03","mg-pcex-test-02","mg-pcex-test-01","mg-test-02","mg-test-01","mg-um-test-01","pcex-activity-demo-02","Hello World! (clone)","Cat Name Program----","Hello World!Hello World!Hello World!","Hello World Challenge","Hello World","Hello World"]]

# for index, activity in enumerate(archived):
#     if activity.get("archived"):
#         resp = requests.delete(f"http://adapt2.sis.pitt.edu/pcex-authoring/api/bulk/activities/{activity['id']}?user={activity['user']}", 
#                             headers={"api-token": open("weat_api_token.txt").read().strip()})
#         print(f"[{index}/{len(archived)}]: {resp.status_code} - {resp.text}")
# Out:
# [0/20]: 200 - {"id":"693c6c7a0204cf59f02a3743"}
# [1/20]: 200 - {"id":"693b91e4e6aa8ff1d74dbf9f"}
# [2/20]: 200 - {"id":"693b7768a100f6c09c868017"}
# [3/20]: 200 - {"id":"693b604da1a3333c6cc7e0a3"}
# [4/20]: 200 - {"id":"693b437565d4582fc64a28f3"}
# [5/20]: 200 - {"id":"693b3d3c80e2aaa929a26014"}
# [6/20]: 200 - {"id":"693b331e80e2aaa929a25a31"}
# [7/20]: 200 - {"id":"693b1a8980e2aaa929a24b54"}
# [8/20]: 200 - {"id":"693b198480e2aaa929a24b2f"}
# [9/20]: 200 - {"id":"693b181c80e2aaa929a249b4"}
# [10/20]: 200 - {"id":"693897d07c5007b9c221adfc"}
# [11/20]: 200 - {"id":"693891ad7c5007b9c221a9b6"}
# [12/20]: 200 - {"id":"69387d6190d59d85f3a5a5e7"}
# [13/20]: 200 - {"id":"6938680f9f169bfc1675a0fc"}
# [14/20]: 200 - {"id":"68ff820b0ec7b27c8794e988"}
# [15/20]: 200 - {"id":"68f5a5577e87b2ff632bd19f"}
# [16/20]: 200 - {"id":"6841a563df5ea13f28e41c50"}
# [17/20]: 200 - {"id":"65c5038abafb6a886b3302d9"}
# [18/20]: 200 - {"id":"65809dd59d944cfd38893c04"}
# ...
